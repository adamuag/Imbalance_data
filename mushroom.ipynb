# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
import seaborn as sns
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import RandomOverSampler

# %%
column_names = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
mushroom_df = pd.read_csv('./uci_repos/mushroom/agaricus-lepiota.data', names=column_names,na_values=['?'])
mushroom_df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
y_train = mushroom_df['class']
x_train = mushroom_df.drop(columns=['class'])
x_train
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# 2               c         b          n           e  ...
# 3               c         n          n           e  ...
# 4               w         b          k           t  ...
# ...           ...       ...        ...         ...  ...
# 8119            c         b          y           e  ...
# 8120            c         b          y           e  ...
# 8121            c         b          n           e  ...
# 8122            c         n          b           t  ...
# 8123            c         b          y           e  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                           s                      w                      w
# 1                           s                      w                      w
# 2                           s                      w                      w
# 3                           s                      w                      w
# 4                           s                      w                      w
# ...                       ...                    ...                    ...
# 8119                        s                      o                      o
# 8120                        s                      o                      o
# 8121                        s                      o                      o
# 8122                        k                      w                      w
# 8123                        s                      o                      o
#
#      veil-type veil-color ring-number ring-type spore-print-color population  \
# 0            p          w           o         p                 k          s
# 1            p          w           o         p                 n          n
# 2            p          w           o         p                 n          n
# 3            p          w           o         p                 k          s
# 4            p          w           o         e                 n          a
# ...        ...        ...         ...       ...               ...        ...
# 8119         p          o           o         p                 b          c
# 8120         p          n           o         p                 b          v
# 8121         p          o           o         p                 b          c
# 8122         p          w           o         e                 w          v
# 8123         p          o           o         p                 o          c
#
#      habitat
# 0          u
# 1          g
# 2          m
# 3          u
# 4          g
# ...      ...
# 8119       l
# 8120       l
# 8121       l
# 8122       l
# 8123       l
#
# [8124 rows x 22 columns]

# %%
label_encoder=LabelEncoder()
for column in x_train.columns:
    x_train[column] = label_encoder.fit_transform(x_train[column])
x_train
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0                0          1           4            0  ...
# 1                0          0           4            0  ...
# 2                0          0           5            0  ...
# 3                0          1           5            0  ...
# 4                1          0           4            1  ...
# ...            ...        ...         ...          ...  ...
# 8119             0          0          11            0  ...
# 8120             0          0          11            0  ...
# 8121             0          0           5            0  ...
# 8122             0          1           0            1  ...
# 8123             0          0          11            0  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            2                       7
# 1                            2                       7
# 2                            2                       7
# 3                            2                       7
# 4                            2                       7
# ...                        ...                     ...
# 8119                         2                       5
# 8120                         2                       5
# 8121                         2                       5
# 8122                         1                       7
# 8123                         2                       5
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          7          0           2            1          4
# 1                          7          0           2            1          4
# 2                          7          0           2            1          4
# 3                          7          0           2            1          4
# 4                          7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 8119                       5          0           1            1          4
# 8120                       5          0           0            1          4
# 8121                       5          0           1            1          4
# 8122                       7          0           2            1          0
# 8123                       5          0           1            1          4
#
#       spore-print-color  population  habitat
# 0                     2           3        5
# 1                     3           2        1
# 2                     3           2        3
# 3                     2           3        5
# 4                     3           0        1
# ...                 ...         ...      ...
# 8119                  0           1        2
# 8120                  0           4        2
# 8121                  0           1        2
# 8122                  7           4        2
# 8123                  4           1        2
#
# [8124 rows x 22 columns]

# %%
x_train.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.348104     1.827671     4.504677     0.415559     4.144756
# std       1.604329     1.229873     2.545821     0.492848     2.103729
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       3.000000     2.000000     4.000000     0.000000     5.000000
# 75%       5.000000     3.000000     8.000000     1.000000     5.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8124.000000   8124.000000  8124.000000  8124.000000  8124.000000
# mean          0.974151      0.161497     0.309207     4.810684     0.567208
# std           0.158695      0.368011     0.462195     3.540359     0.495493
# min           0.000000      0.000000     0.000000     0.000000     0.000000
# 25%           1.000000      0.000000     0.000000     2.000000     0.000000
# 50%           1.000000      0.000000     0.000000     5.000000     1.000000
# 75%           1.000000      0.000000     1.000000     7.000000     1.000000
# max           1.000000      1.000000     1.000000    11.000000     1.000000
#
#        ...  stalk-surface-below-ring  stalk-color-above-ring  \
# count  ...               8124.000000             8124.000000
# mean   ...                  1.603644                5.816347
# std    ...                  0.675974                1.901747
# min    ...                  0.000000                0.000000
# 25%    ...                  1.000000                6.000000
# 50%    ...                  2.000000                7.000000
# 75%    ...                  2.000000                7.000000
# max    ...                  3.000000                8.000000
#
#        stalk-color-below-ring  veil-type   veil-color  ring-number  \
# count             8124.000000     8124.0  8124.000000  8124.000000
# mean                 5.794682        0.0     1.965534     1.069424
# std                  1.907291        0.0     0.242669     0.271064
# min                  0.000000        0.0     0.000000     0.000000
# 25%                  6.000000        0.0     2.000000     1.000000
# 50%                  7.000000        0.0     2.000000     1.000000
# 75%                  7.000000        0.0     2.000000     1.000000
# max                  8.000000        0.0     3.000000     2.000000
#
#          ring-type  spore-print-color   population      habitat
# count  8124.000000        8124.000000  8124.000000  8124.000000
# mean      2.291974           3.596750     3.644018     1.508616
# std       1.801672           2.382663     1.252082     1.719975
# min       0.000000           0.000000     0.000000     0.000000
# 25%       0.000000           2.000000     3.000000     0.000000
# 50%       2.000000           3.000000     4.000000     1.000000
# 75%       4.000000           7.000000     4.000000     2.000000
# max       4.000000           8.000000     5.000000     6.000000
#
# [8 rows x 22 columns]

# %%
x_train = np.array(x_train)
le = LabelEncoder()
y_train  = le.fit_transform(y_train)
np.unique(y_train)
# Out:
# array([0, 1])

# %%
(y_train).tolist().count(0),(y_train).tolist().count(1)
# Out:
# (4208, 3916)

# %%
def group_all_labels(data, num=300, minor=[]):
    # this function is to limit the number of labels that are used
    # it returns the indexes according the labels
    # data is an array of labels
    '''

    :param data: array of labels
    :param num: number required
    :param minor: list of minority indexes
    :return: array of labels indexes
    '''

    labels = np.unique(data)
    co_l = []
    min_col =[]
    if not minor:
        for l in labels:
            el_l = np.where(np.array(data) == l)
            co_l.append(el_l[0])

    else:
        for l in labels:
            if l in minor:
                el_l = np.where(np.array(data) == l)                
                ind = np.random.choice(el_l[0], num)
                co_l.append(ind)
                min_col.append(ind)
    
            else:
                el_l = np.where(np.array(data) == l)
                co_l.append(el_l[0])
    return co_l, min_col

# %%
grouped_labels, min_label = group_all_labels(y_train, 100, [1])
gr_data = []
gr_labels = [] 
for index, q in enumerate(grouped_labels):
    print('class {} : number of samples : {}'.format(index,len(q)))
    for r in q:
        gr_data.append(x_train[r])
        gr_labels.append(y_train[r])
        
x_train = np.array(gr_data)
y_train = np.array(gr_labels)
# Out:
# class 0 : number of samples : 4208
# class 1 : number of samples : 100

# %% [markdown]
# # VAE Model

# %%
import tensorflow.compat.v1  as tf
tf.disable_v2_behavior()
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import os
import numpy as np

mb_size = 32
z_dim = 3
X_dim = x_train.shape[1]
y_dim = len(np.unique(y_train))
h_dim = 3
lr = 1e-3

    
def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / tf.sqrt(in_dim / 2.)
    return tf.random.normal(shape=size, stddev=xavier_stddev)

X = tf.keras.Input(shape=(X_dim,))
c = tf.keras.Input(shape=(y_dim,))
z = tf.keras.Input(shape=(z_dim,))

Q_W1 = tf.Variable(xavier_init([X_dim + y_dim, h_dim]))
Q_b1 = tf.Variable(tf.zeros(shape=[h_dim]))

Q_W2_mu = tf.Variable(xavier_init([h_dim, z_dim]))
Q_b2_mu = tf.Variable(tf.zeros(shape=[z_dim]))

Q_W2_sigma = tf.Variable(xavier_init([h_dim, z_dim]))
Q_b2_sigma = tf.Variable(tf.zeros(shape=[z_dim]))


def Q(X, c):
    inputs = tf.concat(axis=1, values=[X, c])
    h = tf.nn.relu(tf.matmul(inputs, Q_W1) + Q_b1)
    z_mu = tf.matmul(h, Q_W2_mu) + Q_b2_mu
    z_logvar = tf.matmul(h, Q_W2_sigma) + Q_b2_sigma
    return z_mu, z_logvar


def sample_z(mu, log_var):
    eps = tf.random.normal(shape=tf.shape(mu))
    return mu + tf.exp(log_var / 2) * eps

P_W1 = tf.Variable(xavier_init([z_dim + y_dim, h_dim]))
P_b1 = tf.Variable(tf.zeros(shape=[h_dim]))

P_W2 = tf.Variable(xavier_init([h_dim, X_dim]))
P_b2 = tf.Variable(tf.zeros(shape=[X_dim]))


def P(z, c):
    inputs = tf.concat(axis=1, values=[z, c])
    h = tf.nn.relu(tf.matmul(inputs, P_W1) + P_b1)
    logits = tf.matmul(h, P_W2) + P_b2
    prob = tf.nn.sigmoid(logits)
    return prob, logits

z_mu, z_logvar = Q(X, c)
z_sample = sample_z(z_mu, z_logvar)
_, logits = P(z_sample, c)

X_samples, _ = P(z, c)

recon_loss = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=X), 1)
kl_loss = 0.5 * tf.reduce_sum(tf.exp(z_logvar) + z_mu**2 - 1. - z_logvar, 1)
vae_loss = tf.reduce_mean(recon_loss + kl_loss)
# Out:
# WARNING:tensorflow:From /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def generate_sample():
    samples = []
    gen_labels =[]
    for r in range(100):
        for index in range(y_dim):
            gen_labels = gen_labels + [index]*mb_size 
            y = np.zeros([mb_size, y_dim])
            y[range(mb_size), index] = 1 
            samples.extend(sess.run(X_samples,
                                   feed_dict={z: np.random.randn(mb_size, z_dim), c: y}))

    gen_samples = np.array(samples).round(decimals=2)
    gen_labels = np.array(gen_labels)
    print(gen_samples.shape)
    print(gen_labels.shape)
    
    return gen_samples, gen_labels

# %% [markdown]
# # MLP Model

# %%
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, Input, Flatten
from tensorflow.keras.models import Sequential


def build_model(input_shape=(12,), num_classes=2):
    """

    :param input_shape: shape of input_data
    :param num_classes: number of classes
    :return: keras.model.sequential compiled with categorical cross-entropy loss
    """
    model = Sequential([
        Input(shape=input_shape),
        Dense(32, activation="relu"),
        BatchNormalization(),
        Dense(64, activation="relu"),
        BatchNormalization(),
        Flatten(),
        Dropout(0.5),
        Dense(num_classes, activation="softmax"),
    ])

    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    model.summary()
    return model

# %% [markdown]
# # Baseline

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

baseline_list =[]
for i in range(10):

    baseline_model = build_model(input_shape=(x_train.shape[1],),num_classes=y_dim)
    batch_size=32
    epochs=2
    
    X_train, X_test,y_train1,y_test = train_test_split(x_train,y_train, test_size = 0.2)
    y_train_oh = np.array(tf.keras.utils.to_categorical(y_train1, num_classes=y_dim, dtype='float32'))
    test_y = np.array(tf.keras.utils.to_categorical(y_test, num_classes=y_dim, dtype='float32'))
    history_baseline = baseline_model.fit(X_train, y_train_oh, batch_size=batch_size, 
                        epochs=epochs, validation_data=(X_test, test_y))
    score_baseline = baseline_model.evaluate(X_test, test_y, verbose=0)
    print('baseline test loss: ',score_baseline[0])
    print('baseline test accuracy: ', score_baseline[1] )

    y_pred_baseline_oh = baseline_model.predict(X_test)
    y_pred_baseline = y_pred_baseline_oh.argmax(axis=-1)
    baseline_list.append(classification_report(y_test, y_pred_baseline, output_dict=True))
# Out:
# WARNING:tensorflow:From /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/layers/normalization/batch_normalization.py:520: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                736
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 2021-11-02 11:38:44.840151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-02 11:38:44.846381: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2021-11-02 11:38:44.847161: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1835] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-11-02 11:38:44.848178: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3446/3446 [==============================] - 0s 109us/sample - loss: 0.7355 - acc: 0.6651 - val_loss: 0.2077 - val_acc: 0.9756
# Epoch 2/2
# 2112/3446 [=================>............] - ETA: 0s - loss: 0.3660 - acc: 0.8608
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 0s 57us/sample - loss: 0.3299 - acc: 0.8839 - val_loss: 0.1247 - val_acc: 0.9884
# baseline test loss:  0.12473389960981024
# baseline test accuracy:  0.9883991
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                2112
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 3446/3446 [==============================] - 0s 101us/sample - loss: 0.8034 - acc: 0.6584 - val_loss: 0.4121 - val_acc: 0.9049
# Epoch 2/2
# 2176/3446 [=================>............] - ETA: 0s - loss: 0.4030 - acc: 0.8341
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 0s 55us/sample - loss: 0.3597 - acc: 0.8561 - val_loss: 0.1487 - val_acc: 0.9954
# baseline test loss:  0.1486693626559251
# baseline test accuracy:  0.9953596
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 32)                736
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32)                128
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 3446/3446 [==============================] - 0s 129us/sample - loss: 0.7597 - acc: 0.6555 - val_loss: 0.3853 - val_acc: 0.9571
# Epoch 2/2
# 1088/3446 [========>.....................] - ETA: 0s - loss: 0.4387 - acc: 0.8162
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 0s 51us/sample - loss: 0.3514 - acc: 0.8648 - val_loss: 0.1339 - val_acc: 0.9896
# baseline test loss:  0.13391701958364788
# baseline test accuracy:  0.9895592
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 32)                736
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32)                128
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 3446/3446 [==============================] - 0s 139us/sample - loss: 0.7723 - acc: 0.6599 - val_loss: 0.3050 - val_acc: 0.9687
# Epoch 2/2
# 1184/3446 [=========>....................] - ETA: 0s - loss: 0.4202 - acc: 0.8193
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 0s 59us/sample - loss: 0.3482 - acc: 0.8590 - val_loss: 0.1265 - val_acc: 0.9803
# baseline test loss:  0.126525557528654
# baseline test accuracy:  0.98027843
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 3446/3446 [==============================] - 0s 130us/sample - loss: 0.7643 - acc: 0.6686 - val_loss: 0.3208 - val_acc: 0.9629
# Epoch 2/2
#   32/3446 [..............................] - ETA: 0s - loss: 0.4085 - acc: 0.8438
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 0s 54us/sample - loss: 0.3499 - acc: 0.8610 - val_loss: 0.1341 - val_acc: 0.9826
# baseline test loss:  0.13412510233730285
# baseline test accuracy:  0.9825986
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32)                128
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 3446/3446 [==============================] - 0s 138us/sample - loss: 0.8286 - acc: 0.6184 - val_loss: 0.2013 - val_acc: 0.9756
# Epoch 2/2
#   32/3446 [..............................] - ETA: 0s - loss: 0.5118 - acc: 0.7812
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 0s 56us/sample - loss: 0.3611 - acc: 0.8578 - val_loss: 0.1091 - val_acc: 0.9826
# baseline test loss:  0.10907933323399926
# baseline test accuracy:  0.9825986
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 32)                128
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 3446/3446 [==============================] - 1s 148us/sample - loss: 0.7403 - acc: 0.6634 - val_loss: 0.2652 - val_acc: 0.9803
# Epoch 2/2
#   32/3446 [..............................] - ETA: 0s - loss: 0.2930 - acc: 0.8438
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 0s 59us/sample - loss: 0.3390 - acc: 0.8633 - val_loss: 0.1277 - val_acc: 0.9861
# baseline test loss:  0.12768746936680822
# baseline test accuracy:  0.98607886
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32)                128
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 3008/3446 [=========================>....] - ETA: 0s - loss: 0.7851 - acc: 0.6463
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 1s 167us/sample - loss: 0.7526 - acc: 0.6576 - val_loss: 0.1629 - val_acc: 0.9884
# Epoch 2/2
# 3446/3446 [==============================] - 0s 58us/sample - loss: 0.3489 - acc: 0.8595 - val_loss: 0.0899 - val_acc: 0.9884
# baseline test loss:  0.08991532210960743
# baseline test accuracy:  0.9883991
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 32)                128
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 3072/3446 [=========================>....] - ETA: 0s - loss: 0.7308 - acc: 0.6419
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 1s 167us/sample - loss: 0.7039 - acc: 0.6544 - val_loss: 0.2721 - val_acc: 0.9872
# Epoch 2/2
# 3446/3446 [==============================] - 0s 59us/sample - loss: 0.3216 - acc: 0.8874 - val_loss: 0.1229 - val_acc: 0.9907
# baseline test loss:  0.12292567503977818
# baseline test accuracy:  0.99071926
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 32)                128
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 3446 samples, validate on 862 samples
# Epoch 1/2
# 2912/3446 [========================>.....] - ETA: 0s - loss: 0.8408 - acc: 0.6099
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3446/3446 [==============================] - 1s 174us/sample - loss: 0.7988 - acc: 0.6259 - val_loss: 0.2987 - val_acc: 0.9768
# Epoch 2/2
# 3446/3446 [==============================] - 0s 61us/sample - loss: 0.3869 - acc: 0.8485 - val_loss: 0.1523 - val_acc: 0.9768
# baseline test loss:  0.15233668040164386
# baseline test accuracy:  0.9767981

# %%
def post_process_results(b_list, filename='default.csv'):
    total_df = pd.DataFrame(b_list[0]).transpose()
    print('number of runs: {}'.format(len(b_list)))
    for r_dict in b_list[1:]:
        temp = pd.DataFrame(r_dict).transpose()
        total_df = total_df.add(temp)
        
    average_pd = total_df/10.0
    average_pd.to_csv(filename, sep=',')
    
    return average_pd

# %%
post_process_results(baseline_list, 'results_csv/mushroom_baseline_cnn.csv')
# Out:
# number of runs: 10
#               precision    recall  f1-score     support
# 0              0.985956  1.000000  0.992921  841.800000
# 1              1.000000  0.409149  0.556666   20.200000
# accuracy       0.986079  0.986079  0.986079    0.986079
# macro avg      0.992978  0.704575  0.774794  862.000000
# weighted avg   0.986302  0.986079  0.982645  862.000000

# %% [markdown]
# # UnderSampling

# %%
undersampling_list =[]
for i in range(10):

    baseline_model = build_model(input_shape=(x_train.shape[1],),num_classes=y_dim)
    batch_size=32
    epochs=2
    
    X_train, X_test,y_train1,y_test = train_test_split(x_train,y_train, test_size = 0.2)
    rus = RandomUnderSampler(random_state=42)
    X_train, y_train1 = rus.fit_resample(X_train, y_train1)
    
    y_train_oh = np.array(tf.keras.utils.to_categorical(y_train1, num_classes=y_dim, dtype='float32'))
    test_y = np.array(tf.keras.utils.to_categorical(y_test, num_classes=y_dim, dtype='float32'))
    history_baseline = baseline_model.fit(X_train, y_train_oh, batch_size=batch_size, 
                        epochs=epochs, validation_data=(X_test, test_y))
    score_baseline = baseline_model.evaluate(X_test, test_y, verbose=0)
    print('undersampling test loss: ',score_baseline[0])
    print('undersampling test accuracy: ', score_baseline[1] )

    y_pred_baseline_oh = baseline_model.predict(X_test)
    y_pred_baseline = y_pred_baseline_oh.argmax(axis=-1)
    undersampling_list.append(classification_report(y_test, y_pred_baseline, output_dict=True))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 32)                128
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 152 samples, validate on 862 samples
# Epoch 1/2
#  32/152 [=====>........................] - ETA: 0s - loss: 1.4416 - acc: 0.5625
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 152/152 [==============================] - 0s 3ms/sample - loss: 1.1377 - acc: 0.5921 - val_loss: 0.1879 - val_acc: 0.9722
# Epoch 2/2
# 152/152 [==============================] - 0s 304us/sample - loss: 0.9476 - acc: 0.6250 - val_loss: 0.1680 - val_acc: 0.9722
# undersampling test loss:  0.16801169984855122
# undersampling test accuracy:  0.9721578
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 32)                128
# _________________________________________________________________
# dense_34 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 156 samples, validate on 862 samples
# Epoch 1/2
#  32/156 [=====>........................] - ETA: 0s - loss: 0.9395 - acc: 0.5312
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 156/156 [==============================] - 0s 3ms/sample - loss: 0.9689 - acc: 0.5449 - val_loss: 0.1096 - val_acc: 0.9745
# Epoch 2/2
# 156/156 [==============================] - 0s 316us/sample - loss: 0.9379 - acc: 0.6410 - val_loss: 0.1063 - val_acc: 0.9745
# undersampling test loss:  0.10634161070369512
# undersampling test accuracy:  0.97447795
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 32)                128
# _________________________________________________________________
# dense_37 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_38 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 160 samples, validate on 862 samples
# Epoch 1/2
#  32/160 [=====>........................] - ETA: 0s - loss: 0.9145 - acc: 0.5938
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 160/160 [==============================] - 0s 3ms/sample - loss: 1.0671 - acc: 0.5250 - val_loss: 1.5702 - val_acc: 0.0255
# Epoch 2/2
# 160/160 [==============================] - 0s 283us/sample - loss: 0.8550 - acc: 0.6625 - val_loss: 1.2673 - val_acc: 0.0406
# undersampling test loss:  1.2672695314248035
# undersampling test accuracy:  0.040603247
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_39 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 32)                128
# _________________________________________________________________
# dense_40 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 168 samples, validate on 862 samples
# Epoch 1/2
#  32/168 [====>.........................] - ETA: 0s - loss: 1.0735 - acc: 0.4375
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 168/168 [==============================] - 1s 3ms/sample - loss: 1.1830 - acc: 0.5357 - val_loss: 0.1002 - val_acc: 0.9814
# Epoch 2/2
# 168/168 [==============================] - 0s 283us/sample - loss: 0.9221 - acc: 0.6071 - val_loss: 0.0929 - val_acc: 0.9814
# undersampling test loss:  0.09290324784210276
# undersampling test accuracy:  0.9814385
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 32)                128
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 162 samples, validate on 862 samples
# Epoch 1/2
#  32/162 [====>.........................] - ETA: 0s - loss: 1.2009 - acc: 0.3750
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 162/162 [==============================] - 1s 3ms/sample - loss: 1.2585 - acc: 0.4877 - val_loss: 0.2281 - val_acc: 0.9814
# Epoch 2/2
# 162/162 [==============================] - 0s 307us/sample - loss: 1.0318 - acc: 0.5247 - val_loss: 0.2297 - val_acc: 0.9710
# undersampling test loss:  0.2297475805415355
# undersampling test accuracy:  0.9709977
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 32)                128
# _________________________________________________________________
# dense_46 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_47 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 166 samples, validate on 862 samples
# Epoch 1/2
#  32/166 [====>.........................] - ETA: 0s - loss: 2.0277 - acc: 0.3750
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 166/166 [==============================] - 1s 4ms/sample - loss: 1.4447 - acc: 0.4880 - val_loss: 0.1856 - val_acc: 0.9803
# Epoch 2/2
# 166/166 [==============================] - 0s 312us/sample - loss: 1.2453 - acc: 0.5120 - val_loss: 0.1612 - val_acc: 0.9803
# undersampling test loss:  0.16120092225047108
# undersampling test accuracy:  0.98027843
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_48 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 32)                128
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_50 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 168 samples, validate on 862 samples
# Epoch 1/2
#  32/168 [====>.........................] - ETA: 0s - loss: 1.8767 - acc: 0.5625
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 168/168 [==============================] - 1s 4ms/sample - loss: 1.6754 - acc: 0.4048 - val_loss: 0.1270 - val_acc: 0.9814
# Epoch 2/2
# 168/168 [==============================] - 0s 295us/sample - loss: 1.0510 - acc: 0.5536 - val_loss: 0.1175 - val_acc: 0.9814
# undersampling test loss:  0.11746456180191372
# undersampling test accuracy:  0.9814385
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_51 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 32)                128
# _________________________________________________________________
# dense_52 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_53 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 158 samples, validate on 862 samples
# Epoch 1/2
#  32/158 [=====>........................] - ETA: 0s - loss: 1.6275 - acc: 0.4375
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 158/158 [==============================] - 1s 4ms/sample - loss: 1.7881 - acc: 0.3481 - val_loss: 0.9077 - val_acc: 0.3353
# Epoch 2/2
# 158/158 [==============================] - 0s 272us/sample - loss: 1.3989 - acc: 0.4684 - val_loss: 0.6216 - val_acc: 0.6926
# undersampling test loss:  0.6216249290309207
# undersampling test accuracy:  0.6925754
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_54 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 32)                128
# _________________________________________________________________
# dense_55 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_56 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 166 samples, validate on 862 samples
# Epoch 1/2
#  32/166 [====>.........................] - ETA: 0s - loss: 0.7045 - acc: 0.7812
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 166/166 [==============================] - 1s 4ms/sample - loss: 1.0429 - acc: 0.5964 - val_loss: 2.5307 - val_acc: 0.0197
# Epoch 2/2
# 166/166 [==============================] - 0s 322us/sample - loss: 0.7528 - acc: 0.6687 - val_loss: 1.9923 - val_acc: 0.0197
# undersampling test loss:  1.9923187574488381
# undersampling test accuracy:  0.019721577
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_57 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 32)                128
# _________________________________________________________________
# dense_58 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_59 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 168 samples, validate on 862 samples
# Epoch 1/2
#  32/168 [====>.........................] - ETA: 0s - loss: 0.9270 - acc: 0.6562
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 168/168 [==============================] - 1s 4ms/sample - loss: 1.5213 - acc: 0.5179 - val_loss: 0.2022 - val_acc: 0.9780
# Epoch 2/2
# 168/168 [==============================] - 0s 305us/sample - loss: 1.3402 - acc: 0.5298 - val_loss: 0.1490 - val_acc: 0.9826
# undersampling test loss:  0.14900869957393947
# undersampling test accuracy:  0.9825986

# %%
post_process_results(undersampling_list, 'results_csv/mushroom_undersamling.csv')
# Out:
# number of runs: 10
#               precision    recall  f1-score     support
# 0              0.884475  0.769563  0.777119  843.200000
# 1              0.104832  0.313236  0.083743   18.800000
# accuracy       0.759629  0.759629  0.759629    0.759629
# macro avg      0.494654  0.541400  0.430431  862.000000
# weighted avg   0.867095  0.759629  0.761906  862.000000

# %% [markdown]
# # Random Oversampling

# %%
oversampling_list =[]
for i in range(10):

    baseline_model = build_model(input_shape=(x_train.shape[1],),num_classes=y_dim)
    batch_size=32
    epochs=2
    
    X_train, X_test,y_train1,y_test = train_test_split(x_train,y_train, test_size = 0.2)
    ros = RandomOverSampler(random_state=42)
    X_train, y_train1 = ros.fit_resample(X_train, y_train1)
    
    y_train_oh = np.array(tf.keras.utils.to_categorical(y_train1, num_classes=y_dim, dtype='float32'))
    test_y = np.array(tf.keras.utils.to_categorical(y_test, num_classes=y_dim, dtype='float32'))
    history_baseline = baseline_model.fit(X_train, y_train_oh, batch_size=batch_size, 
                        epochs=epochs, validation_data=(X_test, test_y))
    score_baseline = baseline_model.evaluate(X_test, test_y, verbose=0)
    print('oversampling test loss: ',score_baseline[0])
    print('oversampling test accuracy: ', score_baseline[1] )

    y_pred_baseline_oh = baseline_model.predict(X_test)
    y_pred_baseline = y_pred_baseline_oh.argmax(axis=-1)
    oversampling_list.append(classification_report(y_test, y_pred_baseline, output_dict=True))
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_60 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 32)                128
# _________________________________________________________________
# dense_61 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_62 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6734 samples, validate on 862 samples
# Epoch 1/2
# 6144/6734 [==========================>...] - ETA: 0s - loss: 0.4752 - acc: 0.8092
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6734/6734 [==============================] - 1s 174us/sample - loss: 0.4544 - acc: 0.8170 - val_loss: 0.0965 - val_acc: 0.9896
# Epoch 2/2
# 6734/6734 [==============================] - 0s 71us/sample - loss: 0.1410 - acc: 0.9486 - val_loss: 0.0266 - val_acc: 0.9965
# oversampling test loss:  0.02662264828390837
# oversampling test accuracy:  0.99651974
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_63 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 32)                128
# _________________________________________________________________
# dense_64 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_65 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6746 samples, validate on 862 samples
# Epoch 1/2
# 6496/6746 [===========================>..] - ETA: 0s - loss: 0.3974 - acc: 0.8448
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6746/6746 [==============================] - 1s 181us/sample - loss: 0.3899 - acc: 0.8476 - val_loss: 0.1328 - val_acc: 0.9652
# Epoch 2/2
# 6746/6746 [==============================] - 0s 72us/sample - loss: 0.1397 - acc: 0.9429 - val_loss: 0.0459 - val_acc: 0.9872
# oversampling test loss:  0.04594009500126551
# oversampling test accuracy:  0.987239
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 32)                128
# _________________________________________________________________
# dense_67 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_68 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6728 samples, validate on 862 samples
# Epoch 1/2
# 6176/6728 [==========================>...] - ETA: 0s - loss: 0.3838 - acc: 0.8416
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6728/6728 [==============================] - 1s 183us/sample - loss: 0.3694 - acc: 0.8478 - val_loss: 0.0983 - val_acc: 0.9838
# Epoch 2/2
# 6728/6728 [==============================] - 1s 76us/sample - loss: 0.1201 - acc: 0.9547 - val_loss: 0.0264 - val_acc: 0.9930
# oversampling test loss:  0.02641517456767869
# oversampling test accuracy:  0.9930394
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_69 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 32)                128
# _________________________________________________________________
# dense_70 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_71 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6720 samples, validate on 862 samples
# Epoch 1/2
# 6048/6720 [==========================>...] - ETA: 0s - loss: 0.4076 - acc: 0.8297
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6720/6720 [==============================] - 1s 188us/sample - loss: 0.3846 - acc: 0.8393 - val_loss: 0.1007 - val_acc: 0.9814
# Epoch 2/2
# 6720/6720 [==============================] - 0s 72us/sample - loss: 0.1425 - acc: 0.9463 - val_loss: 0.0405 - val_acc: 0.9884
# oversampling test loss:  0.04051455456910443
# oversampling test accuracy:  0.9883991
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_72 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 32)                128
# _________________________________________________________________
# dense_73 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_74 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6734 samples, validate on 862 samples
# Epoch 1/2
# 6688/6734 [============================>.] - ETA: 0s - loss: 0.4038 - acc: 0.8381
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6734/6734 [==============================] - 1s 192us/sample - loss: 0.4028 - acc: 0.8383 - val_loss: 0.1272 - val_acc: 0.9675
# Epoch 2/2
# 6734/6734 [==============================] - 1s 75us/sample - loss: 0.1241 - acc: 0.9519 - val_loss: 0.0291 - val_acc: 0.9930
# oversampling test loss:  0.02909294744465163
# oversampling test accuracy:  0.9930394
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_75 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 32)                128
# _________________________________________________________________
# dense_76 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_77 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6742 samples, validate on 862 samples
# Epoch 1/2
# 6624/6742 [============================>.] - ETA: 0s - loss: 0.4190 - acc: 0.8300
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6742/6742 [==============================] - 1s 198us/sample - loss: 0.4166 - acc: 0.8306 - val_loss: 0.2158 - val_acc: 0.9617
# Epoch 2/2
# 6742/6742 [==============================] - 1s 77us/sample - loss: 0.1396 - acc: 0.9493 - val_loss: 0.0350 - val_acc: 0.9930
# oversampling test loss:  0.03502894560277047
# oversampling test accuracy:  0.9930394
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_78 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 32)                128
# _________________________________________________________________
# dense_79 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_80 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6732 samples, validate on 862 samples
# Epoch 1/2
# 6400/6732 [===========================>..] - ETA: 0s - loss: 0.4133 - acc: 0.8255
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6732/6732 [==============================] - 1s 204us/sample - loss: 0.4019 - acc: 0.8301 - val_loss: 0.1004 - val_acc: 0.9803
# Epoch 2/2
# 6732/6732 [==============================] - 1s 79us/sample - loss: 0.1244 - acc: 0.9531 - val_loss: 0.0365 - val_acc: 0.9954
# oversampling test loss:  0.03646648022629269
# oversampling test accuracy:  0.9953596
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_81 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 32)                128
# _________________________________________________________________
# dense_82 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_83 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6736 samples, validate on 862 samples
# Epoch 1/2
# 6240/6736 [==========================>...] - ETA: 0s - loss: 0.4296 - acc: 0.8287
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6736/6736 [==============================] - 1s 213us/sample - loss: 0.4168 - acc: 0.8336 - val_loss: 0.1564 - val_acc: 0.9559
# Epoch 2/2
# 6736/6736 [==============================] - 1s 89us/sample - loss: 0.1257 - acc: 0.9510 - val_loss: 0.0392 - val_acc: 0.9907
# oversampling test loss:  0.039157054575026176
# oversampling test accuracy:  0.99071926
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_84 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 32)                128
# _________________________________________________________________
# dense_85 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_86 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6742 samples, validate on 862 samples
# Epoch 1/2
# 6592/6742 [============================>.] - ETA: 0s - loss: 0.3702 - acc: 0.8509
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6742/6742 [==============================] - 2s 240us/sample - loss: 0.3646 - acc: 0.8535 - val_loss: 0.1162 - val_acc: 0.9675
# Epoch 2/2
# 6742/6742 [==============================] - 1s 93us/sample - loss: 0.1129 - acc: 0.9571 - val_loss: 0.1471 - val_acc: 0.9524
# oversampling test loss:  0.14708054563562167
# oversampling test accuracy:  0.9524362
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_87 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 32)                128
# _________________________________________________________________
# dense_88 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_89 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 6728 samples, validate on 862 samples
# Epoch 1/2
# 6656/6728 [============================>.] - ETA: 0s - loss: 0.3728 - acc: 0.8609
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 6728/6728 [==============================] - 2s 231us/sample - loss: 0.3702 - acc: 0.8621 - val_loss: 0.0694 - val_acc: 0.9896
# Epoch 2/2
# 6728/6728 [==============================] - 1s 86us/sample - loss: 0.1334 - acc: 0.9524 - val_loss: 0.0303 - val_acc: 0.9942
# oversampling test loss:  0.03030968157103471
# oversampling test accuracy:  0.9941995

# %%
post_process_results(undersampling_list, 'results_csv/mushroom_oversamling.csv')
# Out:
# number of runs: 10
#               precision    recall  f1-score     support
# 0              0.884475  0.769563  0.777119  843.200000
# 1              0.104832  0.313236  0.083743   18.800000
# accuracy       0.759629  0.759629  0.759629    0.759629
# macro avg      0.494654  0.541400  0.430431  862.000000
# weighted avg   0.867095  0.759629  0.761906  862.000000

# %% [markdown]
# # Augmentation experiment

# %%
augment_list =[]
for i in range(10):
    
    X_train, X_test, y_train1, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=40)
    y_train_oh = np.array(tf.keras.utils.to_categorical(y_train1, num_classes=y_dim, dtype='float32'))
    test_y = np.array(tf.keras.utils.to_categorical(y_test, num_classes=y_dim, dtype='float32'))
    
    
    solver = tf.compat.v1.train.AdamOptimizer().minimize(vae_loss)
    sess = tf.compat.v1.Session ()
    sess.run(
    tf.compat.v1.global_variables_initializer())
    
    X_train = np.array(X_train)
    i = 0
    for it in tqdm(range(50000)):
        ind = np.random.choice(X_train.shape[0], mb_size)
        X_mb = np.array(X_train[ind])
        y_mb = np.array(y_train_oh[ind])

        _, loss = sess.run([solver, vae_loss], feed_dict={X: X_mb, c: y_mb})

    
    gen_samples, gen_labels = generate_sample()
    x = np.concatenate([X_train, gen_samples])
    y = np.concatenate([y_train1, gen_labels])
    x = np.array(x)
    y_oh = np.array(tf.keras.utils.to_categorical(y, num_classes=y_dim, dtype='float32'))
    
    aug_model = build_model(input_shape=(x_train.shape[1],),num_classes=y_dim)
    batch_size=32
    epochs=2
    hist = aug_model.fit(x, y_oh, batch_size=batch_size, epochs=epochs, 
                            validation_data=(X_test, test_y))
    
    y_pred_aug_oh = aug_model.predict(X_test)
    y_pred_aug = y_pred_aug_oh.argmax(axis=-1)
    augment_list.append(classification_report(y_test, y_pred_aug, output_dict=True) )
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:42<00:00, 1188.36it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_90 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 32)                128
# _________________________________________________________________
# dense_91 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_92 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9408/9846 [===========================>..] - ETA: 0s - loss: 0.5358 - acc: 0.7393
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 189us/sample - loss: 0.5310 - acc: 0.7422 - val_loss: 0.0707 - val_acc: 0.9826
# Epoch 2/2
# 9846/9846 [==============================] - 1s 85us/sample - loss: 0.3152 - acc: 0.8558 - val_loss: 0.0680 - val_acc: 0.9838
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:41<00:00, 1211.07it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_93 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 32)                128
# _________________________________________________________________
# dense_94 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_95 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9568/9846 [============================>.] - ETA: 0s - loss: 0.4842 - acc: 0.7664
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 207us/sample - loss: 0.4795 - acc: 0.7691 - val_loss: 0.0492 - val_acc: 0.9849
# Epoch 2/2
# 9846/9846 [==============================] - 1s 86us/sample - loss: 0.2837 - acc: 0.8739 - val_loss: 0.0490 - val_acc: 0.9884
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:41<00:00, 1210.11it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_96 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 32)                128
# _________________________________________________________________
# dense_97 (Dense)             (None, 64)                2112
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_98 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9504/9846 [===========================>..] - ETA: 0s - loss: 0.5801 - acc: 0.7189
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 199us/sample - loss: 0.5763 - acc: 0.7208 - val_loss: 0.0750 - val_acc: 0.9814
# Epoch 2/2
# 9846/9846 [==============================] - 1s 86us/sample - loss: 0.3855 - acc: 0.8222 - val_loss: 0.0466 - val_acc: 0.9861
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:41<00:00, 1209.83it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_99 (Dense)             (None, 32)                736
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 32)                128
# _________________________________________________________________
# dense_100 (Dense)            (None, 64)                2112
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_101 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9824/9846 [============================>.] - ETA: 0s - loss: 0.5926 - acc: 0.6768
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 208us/sample - loss: 0.5923 - acc: 0.6769 - val_loss: 0.0713 - val_acc: 0.9826
# Epoch 2/2
# 9846/9846 [==============================] - 1s 86us/sample - loss: 0.4493 - acc: 0.7566 - val_loss: 0.0551 - val_acc: 0.9907
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:41<00:00, 1196.26it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_102 (Dense)            (None, 32)                736
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 32)                128
# _________________________________________________________________
# dense_103 (Dense)            (None, 64)                2112
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_34 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_104 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9728/9846 [============================>.] - ETA: 0s - loss: 0.5716 - acc: 0.7260
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 215us/sample - loss: 0.5700 - acc: 0.7268 - val_loss: 0.0624 - val_acc: 0.9849
# Epoch 2/2
# 9846/9846 [==============================] - 1s 90us/sample - loss: 0.4063 - acc: 0.7976 - val_loss: 0.0445 - val_acc: 0.9907
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:42<00:00, 1189.75it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_105 (Dense)            (None, 32)                736
# _________________________________________________________________
# batch_normalization_70 (Batc (None, 32)                128
# _________________________________________________________________
# dense_106 (Dense)            (None, 64)                2112
# _________________________________________________________________
# batch_normalization_71 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_35 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_107 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9344/9846 [===========================>..] - ETA: 0s - loss: nan - acc: 0.6657
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 224us/sample - loss: nan - acc: 0.6665 - val_loss: nan - val_acc: 0.9814
# Epoch 2/2
# 9846/9846 [==============================] - 1s 92us/sample - loss: nan - acc: 0.6665 - val_loss: nan - val_acc: 0.9814
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:42<00:00, 1184.91it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_108 (Dense)            (None, 32)                736
# _________________________________________________________________
# batch_normalization_72 (Batc (None, 32)                128
# _________________________________________________________________
# dense_109 (Dense)            (None, 64)                2112
# _________________________________________________________________
# batch_normalization_73 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_110 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9344/9846 [===========================>..] - ETA: 0s - loss: 0.6086 - acc: 0.6968
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 232us/sample - loss: 0.5974 - acc: 0.7032 - val_loss: 0.0761 - val_acc: 0.9814
# Epoch 2/2
# 9846/9846 [==============================] - 1s 92us/sample - loss: 0.3991 - acc: 0.8045 - val_loss: 0.0530 - val_acc: 0.9884
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:41<00:00, 1193.01it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_111 (Dense)            (None, 32)                736
# _________________________________________________________________
# batch_normalization_74 (Batc (None, 32)                128
# _________________________________________________________________
# dense_112 (Dense)            (None, 64)                2112
# _________________________________________________________________
# batch_normalization_75 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_37 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_113 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9728/9846 [============================>.] - ETA: 0s - loss: 0.6305 - acc: 0.6798
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 241us/sample - loss: 0.6280 - acc: 0.6809 - val_loss: 0.0696 - val_acc: 0.9838
# Epoch 2/2
# 9846/9846 [==============================] - 1s 95us/sample - loss: 0.4465 - acc: 0.7642 - val_loss: 0.0541 - val_acc: 0.9907
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:42<00:00, 1175.48it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_114 (Dense)            (None, 32)                736
# _________________________________________________________________
# batch_normalization_76 (Batc (None, 32)                128
# _________________________________________________________________
# dense_115 (Dense)            (None, 64)                2112
# _________________________________________________________________
# batch_normalization_77 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_38 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_116 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9440/9846 [===========================>..] - ETA: 0s - loss: 0.2635 - acc: 0.9006
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 2s 252us/sample - loss: 0.2560 - acc: 0.9041 - val_loss: 0.0513 - val_acc: 0.9861
# Epoch 2/2
# 9846/9846 [==============================] - 1s 96us/sample - loss: 0.0494 - acc: 0.9892 - val_loss: 0.0563 - val_acc: 0.9872
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:42<00:00, 1170.85it/s]
# (6400, 22)
# (6400,)
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_117 (Dense)            (None, 32)                736
# _________________________________________________________________
# batch_normalization_78 (Batc (None, 32)                128
# _________________________________________________________________
# dense_118 (Dense)            (None, 64)                2112
# _________________________________________________________________
# batch_normalization_79 (Batc (None, 64)                256
# _________________________________________________________________
# flatten_39 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_119 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 3,362
# Trainable params: 3,170
# Non-trainable params: 192
# _________________________________________________________________
# Train on 9846 samples, validate on 862 samples
# Epoch 1/2
# 9846/9846 [==============================] - ETA: 0s - loss: 0.5485 - acc: 0.7329
# /media/adamu/data/projects/notebooks/UCI_encoders/imbalance_venv/lib/python3.8/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 9846/9846 [==============================] - 3s 269us/sample - loss: 0.5485 - acc: 0.7329 - val_loss: 0.0797 - val_acc: 0.9814
# Epoch 2/2
# 9846/9846 [==============================] - 1s 98us/sample - loss: 0.3726 - acc: 0.8226 - val_loss: 0.0592 - val_acc: 0.9896

# %%
post_process_results(augment_list, 'results_csv/mushroom_VAE.csv')
# Out:
# number of runs: 10
#               precision    recall  f1-score     support
# 0              0.989239  0.998345  0.993766  846.000000
# 1              0.781079  0.425000  0.535591   16.000000
# accuracy       0.987703  0.987703  0.987703    0.987703
# macro avg      0.885159  0.711673  0.764678  862.000000
# weighted avg   0.985375  0.987703  0.985261  862.000000
